# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/piyush-an/DAMG7245-Summer23/blob/main/fastapi-streamlit/Authentication.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <!-- https://openincolab.com/ -->

# %% [markdown]
# ## Part A : Password Verification
#
# Compare the user input to the password stored has hash in a database
#
#
# #### Passlib
#
# Link - https://passlib.readthedocs.io/en/stable/index.html#
#
# Passlib is a password hashing library for Python 2 & 3, which provides cross-platform implementations of over 30 password hashing algorithms, as well as a framework for managing existing password hashes. It’s designed to be useful for a wide range of tasks, from verifying a hash found in /etc/shadow, to providing full-strength password hashing for multi-user application.

# %%
# %pip install python-jose
# %pip install passlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-jose
#   Downloading python_jose-3.3.0-py2.py3-none-any.whl (33 kB)
# Collecting ecdsa!=0.15 (from python-jose)
#   Downloading ecdsa-0.18.0-py2.py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from python-jose) (4.9)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from python-jose) (0.5.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from ecdsa!=0.15->python-jose) (1.16.0)
# Installing collected packages: ecdsa, python-jose
# Successfully installed ecdsa-0.18.0 python-jose-3.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting passlib
#   Downloading passlib-1.7.4-py2.py3-none-any.whl (525 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 32.0 MB/s eta 0:00:00
# Installing collected packages: passlib
# Successfully installed passlib-1.7.4

# %%
from passlib.context import CryptContext

# %%
pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

# %% [markdown]
# ### Create a hash for plain text password and store it into database

# %%
def get_password_hash(password):
    return pwd_context.hash(password)

# %%
user_password = "qwerty12345"

# %%
get_password_hash(user_password)
# Out:
# '$2b$12$rOpblIzdi/wXbT6T6ytanuEY1E1Hso8DjlXp9ufnn5LAy5KBdNnk6'

# %% [markdown]
# Store the hashed password into a user table in a database
#
# | User_Name | Full_Name | Hashed_Password                                              | Email_id      | Active |
# |----------|-----------|--------------------------------------------------------------|---------------|--------|
# | demouser | Demo User | $2b$12$AvohtpEiPFS7fgewSJQMkeqJlUvi4rgVu713WNEh/l1iqnYYVgevO | demo@user.com | true   |

# %% [markdown]
# ### Validate the user upon login request

# %%
def verify_password(plain_password, hashed_password):
    return pwd_context.verify(plain_password, hashed_password)

# %%
user_enters_password = "someotherpassword"

# %%
verify_password(user_enters_password, get_password_hash(user_password))
# Out:
# False

# %%
user_enters_password = "qwerty12345"

# %%
verify_password(user_enters_password, get_password_hash(user_password))
# Out:
# True

# %% [markdown]
# ## Part B : Create Access Token
#
# Once the user is authenticated, create access tokens with time validity to continue using the service without the need to login and authenticate for each reuqest.

# %%
import time
from jose import jwt
from datetime import datetime, timedelta

# %%
# to get a string like this run:
# openssl rand -hex 32
SECRET_KEY = "09d25e094faa6ca2556c818166b7a9563b93f7099f6f0f4caa6cf63b88e8d3e7"
ALGORITHM = "HS256"
ACCESS_TOKEN_EXPIRE_MINUTES = 30

# %%
user_data = dict()
user_data["username"] = "demouser"
user_data["password"] = get_password_hash("some@Strong_Password#123")

# %%
def create_access_token(data: dict):
    to_encode = data.copy()
    expire = datetime.utcnow() + timedelta(minutes=ACCESS_TOKEN_EXPIRE_MINUTES)
    to_encode.update({"exp": expire})
    encoded_jwt = jwt.encode(to_encode, SECRET_KEY, algorithm=ALGORITHM)
    return encoded_jwt

# %%
generated_token = create_access_token(user_data)
print(generated_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6ImRlbW91c2VyIiwicGFzc3dvcmQiOiIkMmIkMTIkazIxbXZhRjB2WUtQbVBNN05UZmw2T1NzSEF6SzlyVTE3UjZKNGRBMldMeTc5Z0x4bmp6MVMiLCJleHAiOjE2ODYwMzI4Mjh9.zxy6b-n14YtB9DZKdWCbR5TiRVe_SzPyp3Y1HL-XztY

# %%
decoded_token = jwt.decode(generated_token, SECRET_KEY, algorithms=[ALGORITHM])
decoded_token
# Out:
# {'username': 'demouser',
#  'password': '$2b$12$k21mvaF0vYKPmPM7NTfl6OSsHAzK9rU17R6J4dA2WLy79gLxnjz1S',
#  'exp': 1686032828}

# %%
def compare_time(token_time: int):
  if int(time.time()) < token_time:
    return True
  else:
    return False

# %%
compare_time(decoded_token['exp'])
# Out:
# True

# %% [markdown]
# ## OpenAI API Service
#
# https://platform.openai.com/docs/guides/embeddings

# %%
# %pip install openai
# %pip install getpass4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.7-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Collecting aiohttp (from openai)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.9 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.7 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.7 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting getpass4
#   Downloading getpass4-0.0.14.1-py3-none-any.whl (8.7 kB)
# Collecting caugetch (from getpass4)
#   Downloading caugetch-0.0.1-py3-none-any.whl (3.4 kB)
# Collecting clipboard (from getpass4)
#   Downloading clipboard-0.0.4.tar.gz (1.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting colorama (from getpass4)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting pyperclip (from getpass4)
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: clipboard, pyperclip
#   Building wheel for clipboard (setup.py) ... done
#   Created wheel for clipboard: filename=clipboard-0.0.4-py3-none-any.whl size=1849 sha256=d502f7e9411a2229234de7851aabc1ba6913ef0821858118ffdd11a34945a02b
#   Stored in directory: /root/.cache/pip/wheels/a9/16/29/0b45762bf14ad4ba5495cd4ce66c7e326ecb0d5f1edeb7c94d
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11124 sha256=abe3c8f68aa20c9b46746225a68b7f1bdf351513195fdb589ca79b018cd0a6ad
#   Stored in directory: /root/.cache/pip/wheels/04/24/fe/140a94a7f1036003ede94579e6b4227fe96c840c6f4dcbe307
# Successfully built clipboard pyperclip
# Installing collected packages: pyperclip, colorama, clipboard, caugetch, getpass4
# Successfully installed caugetch-0.0.1 clipboard-0.0.4 colorama-0.4.6 getpass4-0.0.14.1 pyperclip-1.8.2

# %%
import openai
from getpass import getpass
openai_api_key = getpass('Enter OpenAI API KEY: ')
# Out:
# Enter OpenAI API KEY: ··········

# %%
openai.api_key = openai_api_key
def get_embedding(user_input : str):
  response = openai.Embedding.create(
      input=user_input,
      model="text-embedding-ada-002" # More models at https://platform.openai.com/docs/guides/embeddings/embedding-models
  )
  embeddings = response['data'][0]['embedding']
  return embeddings

# %%
get_embedding("This is an example to test embedding using OpenAI")
# Out:
# [-0.02404232881963253,
#  -0.005013434682041407,
#  0.0013788676587864757,
#  0.005013434682041407,
#  0.007561699952930212,
#  0.012069636955857277,
#  0.004269036930054426,
#  0.0060382806695997715,
#  -0.020039889961481094,
#  -0.03742071986198425,
#  0.009500597603619099,
#  0.024914832785725594,
#  0.003874332644045353,
#  -0.013980835676193237,
#  0.011605686508119106,
#  0.019250482320785522,
#  0.010795503854751587,
#  0.009022797457873821,
#  0.015677370131015778,
#  -0.016355985775589943,
#  -0.0038154732901602983,
#  -0.0020635409746319056,
#  -0.01187574677169323,
#  0.003908955957740545,
#  -0.013392241671681404,
#  -0.0083095608279109,
#  0.014015458524227142,
#  -0.04262804612517357,
#  -0.009763733483850956,
#  -0.025621145963668823,
#  0.03055148385465145,
#  -0.007901007309556007,
#  0.003242459846660495,
#  -0.028889572247862816,
#  -0.008932777680456638,
#  -0.0038708702195435762,
#  0.002882378874346614,
#  -0.022574305534362793,
#  0.03160402923822403,
#  -0.007097749505192041,
#  0.0026053935289382935,
#  0.011709555983543396,
#  -0.001141699030995369,
#  -0.026202814653515816,
#  -0.024014629423618317,
#  0.007762514520436525,
#  -0.013593056239187717,
#  -0.01979060284793377,
#  0.003387877019122243,
#  0.010165362618863583,
#  0.019832151010632515,
#  0.03132704272866249,
#  -0.02913885936141014,
#  0.009881452657282352,
#  -0.00645375857129693,
#  0.018682662397623062,
#  -0.019887547940015793,
#  0.02566269226372242,
#  0.004909565206617117,
#  -0.0077071175910532475,
#  -0.01495720911771059,
#  9.937931463355199e-05,
#  -0.006415673065930605,
#  0.005920561961829662,
#  -0.01753317192196846,
#  0.0028771853540092707,
#  0.010373101569712162,
#  0.012111184187233448,
#  0.033847611397504807,
#  0.0034311560448259115,
#  0.026770634576678276,
#  0.010733182542026043,
#  -0.007090825121849775,
#  -0.004230951424688101,
#  0.020593861117959023,
#  0.002948162844404578,
#  -0.013440714217722416,
#  -0.005356204230338335,
#  0.009078195318579674,
#  0.004625655245035887,
#  0.00848960131406784,
#  -0.024222368374466896,
#  0.0015216883039101958,
#  0.037448421120643616,
#  0.02071850374341011,
#  -0.009666788391768932,
#  -0.010511593893170357,
#  0.030579183250665665,
#  -0.00037695973878726363,
#  -0.003926267381757498,
#  0.019250482320785522,
#  0.010033794678747654,
#  0.0004185075522400439,
#  0.017020750790834427,
#  -0.02969283051788807,
#  0.01923663355410099,
#  -0.008918927982449532,
#  0.028529491275548935,
#  0.00898125022649765,
#  -0.027407700195908546,
#  -0.0024132349062711,
#  0.0035973472986370325,
#  -0.024208519607782364,
#  -0.016951503232121468,
#  -0.034761663526296616,
#  0.003964352887123823,
#  0.008157218806445599,
#  -0.013288372196257114,
#  0.0065126181580126286,
#  0.016840709373354912,
#  0.0024997927248477936,
#  0.015178796835243702,
#  -0.004663740750402212,
#  -0.04708750918507576,
#  -0.02607817016541958,
#  0.017200790345668793,
#  0.005248872563242912,
#  -0.02530261129140854,
#  -0.023502206429839134,
#  0.00016727318870835006,
#  0.01209041103720665,
#  0.04728139936923981,
#  -0.0026417477056384087,
#  -0.006104064639657736,
#  0.01789325289428234,
#  -0.0008746678358875215,
#  -0.007018116302788258,
#  -0.018793456256389618,
#  -0.015081852674484253,
#  -0.021549459546804428,
#  0.026493648067116737,
#  0.012076561339199543,
#  0.02502562664449215,
#  -0.0007422341732308269,
#  -0.03373681753873825,
#  0.04171399399638176,
#  -0.001043888507410884,
#  0.0056989737786352634,
#  -0.03232419118285179,
#  -0.010670860297977924,
#  0.010414648801088333,
#  0.026922976598143578,
#  -0.002719649812206626,
#  0.009244386106729507,
#  -0.024707093834877014,
#  0.014147026464343071,
#  -0.000801526359282434,
#  -0.0016307512996718287,
#  0.0141054792329669,
#  -0.010310779325664043,
#  0.00936902966350317,
#  -0.009742959402501583,
#  -0.029803624376654625,
#  0.01537268701940775,
#  0.0009322288096882403,
#  0.029166556894779205,
#  0.01456942968070507,
#  0.009895301423966885,
#  -0.02326676994562149,
#  -0.005653963424265385,
#  0.013288372196257114,
#  0.010989394038915634,
#  -0.03370911628007889,
#  -0.016134396195411682,
#  0.011252529919147491,
#  0.02461014874279499,
#  0.03174252063035965,
#  -0.0075478507205843925,
#  0.003929729573428631,
#  -0.020275328308343887,
#  -0.023931534960865974,
#  0.026493648067116737,
#  -0.02877877838909626,
#  0.009334406815469265,
#  0.00792178139090538,
#  0.0015173603314906359,
#  0.01576046645641327,
#  -0.004507936537265778,
#  -0.0030260649509727955,
#  -0.023986931890249252,
#  -0.008939702063798904,
#  0.01648062840104103,
#  0.031077755615115166,
#  0.01937512494623661,
#  0.004179016686975956,
#  -0.021881842985749245,
#  0.005051520187407732,
#  -0.017491625621914864,
#  0.006993880029767752,
#  -0.010933997109532356,
#  0.018682662397623062,
#  0.03653436899185181,
#  0.011058639734983444,
#  0.006827688775956631,
#  -0.6492536664009094,
#  -0.014091629534959793,
#  0.025081023573875427,
#  -0.009362105280160904,
#  0.021895691752433777,
#  0.02616126649081707,
#  -0.0017900178208947182,
#  -0.02311442792415619,
#  -0.007201618980616331,
#  0.044927023351192474,
#  -0.004372906405478716,
#  -0.004909565206617117,
#  -0.028446394950151443,
#  0.007880233228206635,
#  0.02523336559534073,
#  -0.022172678261995316,
#  0.01754702255129814,
#  -0.022020336240530014,
#  0.011917294934391975,
#  0.032905858010053635,
#  -0.0073816594667732716,
#  0.004760685842484236,
#  0.007499378174543381,
#  -0.0019994881004095078,
#  -0.005584717262536287,
#  0.0077140419743955135,
#  -0.006325652822852135,
#  -0.007270865608006716,
#  0.03124394826591015,
#  0.011820349842309952,
#  -0.018336430191993713,
#  0.012311998754739761,
#  0.020870845764875412,
#  0.010255382396280766,
#  0.03852866217494011,
#  -0.01353765930980444,
#  -0.029221953824162483,
#  0.005553556140512228,
#  -0.005889400839805603,
#  0.03343213349580765,
#  -0.025261064991354942,
#  0.004521785769611597,
#  -0.003211298957467079,
#  -0.0006457220879383385,
#  -0.014458635821938515,
#  0.01889040134847164,
#  0.0040024383924901485,
#  -0.00693155825138092,
#  -0.024236219003796577,
#  0.01966596022248268,
#  -0.005726672243326902,
#  0.03218569606542587,
#  -0.007672494277358055,
#  -0.0077417404390871525,
#  -0.0013797333231195807,
#  -0.012699778191745281,
#  0.02913885936141014,
#  0.00851729977875948,
#  0.025081023573875427,
#  -0.002041035797446966,
#  -0.0029412382282316685,
#  0.013025236316025257,
#  -0.03797469288110733,
#  -0.0075409263372421265,
#  -0.019915247336030006,
#  0.0012507620267570019,
#  -0.00636373832821846,
#  0.03096696175634861,
#  -0.009583692997694016,
#  -0.05154697224497795,
#  0.031216248869895935,
#  0.0075132278725504875,
#  -0.022144978865981102,
#  0.0009062614408321679,
#  0.0034605858381837606,
#  0.034761663526296616,
#  0.007443981245160103,
#  -0.011716480366885662,
#  -0.029997512698173523,
#  0.02204803377389908,
#  0.00792178139090538,
#  -0.017422378063201904,
#  -0.0037946992088109255,
#  -0.007582474034279585,
#  0.01339916605502367,
#  0.012789798900485039,
#  -0.03933192044496536,
#  0.013634604401886463,
#  0.003311706008389592,
#  -0.004829932004213333,
#  0.019111989066004753,
#  0.035177141427993774,
#  -0.04384678229689598,
#  -0.02121707797050476,
#  0.0072085438296198845,
#  -0.0019008120289072394,
#  0.005546631757169962,
#  0.011813425458967686,
#  0.04121541976928711,
#  -0.009929925203323364,
#  0.005321580916643143,
#  -0.006024431437253952,
#  0.002134518465027213,
#  0.002440933370962739,
#  0.026341307908296585,
#  -0.000617590791080147,
#  -2.6995252483175136e-05,
#  0.018405675888061523,
#  -0.004355594515800476,
#  -0.03401380032300949,
#  -0.03470626473426819,
#  -0.022602004930377007,
#  -0.00012518439325504005,
#  0.0012827884638682008,
#  0.0031472460832446814,
#  -0.03816858306527138,
#  0.004843781236559153,
#  0.0014308025129139423,
#  0.024623997509479523,
#  -0.018973495811223984,
#  0.008510375395417213,
#  -0.0011884402483701706,
#  0.01227045152336359,
#  0.012879818677902222,
#  0.001660180976614356,
#  0.003877794835716486,
#  -0.014237047173082829,
#  -0.022241923958063126,
#  -0.018073294311761856,
#  0.009015873074531555,
#  0.0135099608451128,
#  -0.011127886362373829,
#  0.014057006686925888,
#  -0.010442348197102547,
#  0.04024597257375717,
#  0.0032095678616315126,
#  0.011764952912926674,
#  -0.006692658644169569,
#  0.011661083437502384,
#  0.001274998183362186,
#  0.00473644956946373,
#  0.01166800782084465,
#  0.00858654547482729,
#  -0.0075755491852760315,
#  -0.04093843325972557,
#  -0.008420354686677456,
#  -0.02021993137896061,
#  0.0020635409746319056,
#  0.0018229098059237003,
#  -0.0026781021151691675,
#  0.0014316680608317256,
#  -0.013288372196257114,
#  0.004597956780344248,
#  0.011086339130997658,
#  -0.01322605088353157,
#  -0.019125837832689285,
#  -0.01725618727505207,
#  -0.026826031506061554,
#  -0.004372906405478716,
#  -0.01992909610271454,
#  0.01873805932700634,
#  0.014057006686925888,
#  0.002498061629012227,
#  -0.0014524419093504548,
#  -0.012048862874507904,
#  0.020953942090272903,
#  -0.007804062217473984,
#  0.038916442543268204,
#  -0.03246268257498741,
#  -0.02735230326652527,
#  0.0015277473721653223,
#  -0.03243498504161835,
#  0.001372808706946671,
#  0.01817023940384388,
#  -0.0007089094142429531,
#  0.019555166363716125,
#  -0.04257264733314514,
#  -0.008912003599107265,
#  -0.0036942921578884125,
#  -0.025925828143954277,
#  -0.006533391773700714,
#  0.00232321466319263,
#  0.01011689007282257,
#  -0.0034467363730072975,
#  0.014804867096245289,
#  0.0127621004357934,
#  0.021452516317367554,
#  0.020496916025877,
#  -0.00645375857129693,
#  0.0056989737786352634,
#  -0.010193061083555222,
#  0.028723381459712982,
#  -0.021743349730968475,
#  0.03332133963704109,
#  0.009805281646549702,
#  0.006502231117337942,
#  -0.005460073705762625,
#  0.007312413305044174,
#  0.008448053151369095,
#  0.021480213850736618,
#  0.01425089593976736,
#  -0.0038085486739873886,
#  0.0083095608279109,
#  -0.010137664154171944,
#  0.0067342063412070274,
#  -0.02269895002245903,
#  -0.014167800545692444,
#  -0.01710384525358677,
#  0.027476947754621506,
#  0.010442348197102547,
#  0.02249121107161045,
#  0.01357920654118061,
#  -0.02524721436202526,
#  0.0018523395992815495,
#  0.009846828877925873,
#  0.008177992887794971,
#  -0.001990832155570388,
#  0.011654159054160118,
#  -0.011155584827065468,
#  0.0010309048229828477,
#  -0.028335601091384888,
#  0.006325652822852135,
#  0.015192646533250809,
#  -0.0006284104892984033,
#  -0.006935020908713341,
#  0.01830873265862465,
#  0.0045598712749779224,
#  0.005273108836263418,
#  0.015303440392017365,
#  -0.03742071986198425,
#  0.005491234827786684,
#  0.024277765303850174,
#  0.0023630312643945217,
#  0.009479823522269726,
#  0.017990197986364365,
#  -0.006938483100384474,
#  0.013870041817426682,
#  0.02157715894281864,
#  0.025911979377269745,
#  -0.011854972690343857,
#  -0.0019527467666193843,
#  0.012886743061244488,
#  0.026881428435444832,
#  -0.029859021306037903,
#  0.03714373707771301,
#  0.01552502904087305,
#  0.034761663526296616,
#  0.01589895971119404,
#  -0.033930703997612,
#  0.004933801479637623,
#  -0.0171176940202713,
#  -0.0032528466545045376,
#  0.0021881842985749245,
#  0.011758028529584408,
#  0.015441933646798134,
#  0.0018315656343474984,
#  -0.02285129204392433,
#  0.00781791191548109,
#  0.007360885851085186,
#  0.03027449920773506,
#  -0.006941945292055607,
#  0.010276156477630138,
#  0.013087557628750801,
#  0.002846024464815855,
#  0.019887547940015793,
#  -0.018128691241145134,
#  -0.026715237647294998,
#  -0.01364152878522873,
#  -0.02099549025297165,
#  -4.86617827846203e-05,
#  -0.02164640463888645,
#  -0.01226352620869875,
#  -0.0026486723218113184,
#  -0.006398361641913652,
#  0.0373099260032177,
#  0.01343378983438015,
#  0.013246824033558369,
#  0.017713213339447975,
#  0.014527881518006325,
#  0.03019140288233757,
#  -0.007838685065507889,
#  -0.041603200137615204,
#  0.040910735726356506,
#  -0.008240314200520515,
#  -0.008268012665212154,
#  -0.012035013176500797,
#  -0.03805778920650482,
#  0.001493989722803235,
#  -0.013357618823647499,
#  0.008164143189787865,
#  0.000835716724395752,
#  0.028723381459712982,
#  0.013752322643995285,
#  -0.004677589982748032,
#  0.0077417404390871525,
#  0.04032906889915466,
#  0.023294467478990555,
#  -0.009410576894879341,
#  0.011896520853042603,
#  -0.02765698730945587,
#  0.006644186098128557,
#  -0.0022210762836039066,
#  -0.0010023406939581037,
#  -0.004944188520312309,
#  0.02376534231007099,
#  -0.0072362422943115234,
#  -0.002700607292354107,
#  -0.004691439215093851,
#  -0.020136835053563118,
#  -0.02786472626030445,
#  0.001344244577921927,
#  0.004466388840228319,
#  -0.0032078365329653025,
#  -0.009389803744852543,
#  0.024014629423618317,
#  0.010850900784134865,
#  -0.009729110635817051,
#  -0.009202837944030762,
#  0.018364129588007927,
#  0.018931949511170387,
#  -0.010019944980740547,
#  -0.010054567828774452,
#  -0.01768551394343376,
#  0.01209041103720665,
#  0.04863862693309784,
#  0.015732768923044205,
#  -0.0096529396250844,
#  0.0010715870885178447,
#  -0.02325292117893696,
#  -0.00024344415578525513,
#  -0.03556491807103157,
#  0.006076366174966097,
#  0.0008950089104473591,
#  0.011571062728762627,
#  -0.032213397324085236,
#  -0.005858240183442831,
#  0.01660527102649212,
#  -0.005300807300955057,
#  0.03141013905405998,
#  0.004317509010434151,
#  0.0002562114386819303,
#  -0.014791017398238182,
#  0.018225636333227158,
#  -0.005238485522568226,
#  0.002740423893555999,
#  -0.0037393022794276476,
#  -0.011169434525072575,
#  -0.009514447301626205,
#  0.02454090304672718,
#  -0.011619535274803638,
#  0.020095286890864372,
#  0.010165362618863583,
#  -0.015289591625332832,
#  -0.03296125680208206,
#  0.01312218140810728,
#  -0.0012819227995350957,
#  0.003045107703655958,
#  0.009015873074531555,
#  -0.00993684958666563,
#  0.0184610728174448,
#  -0.0014827372506260872,
#  0.03664516285061836,
#  0.010373101569712162,
#  0.001902543124742806,
#  -0.0014723502099514008,
#  0.022726647555828094,
#  -0.010913223028182983,
#  -0.004913027863949537,
#  -0.009182064794003963,
#  -0.000656109070405364,
#  -0.011349475011229515,
#  0.0037496890872716904,
#  -0.007831760682165623,
#  -0.02800321951508522,
#  0.01262360718101263,
#  0.006502231117337942,
#  -0.02559344656765461,
#  0.0024426644667983055,
#  0.014320142567157745,
#  0.02566269226372242,
#  -0.014458635821938515,
#  -0.006547241471707821,
#  -0.001138236722908914,
#  -0.026119718328118324,
#  -0.033404432237148285,
#  -0.023003634065389633,
#  -0.013870041817426682,
#  -0.013073708862066269,
#  -0.021535610780119896,
#  -0.014320142567157745,
#  -0.002681564539670944,
#  -0.002222807379439473,
#  -0.020026041194796562,
#  0.0005929217441007495,
#  0.004327896051108837,
#  -0.017145393416285515,
#  -0.04154780134558678,
#  -0.019042743369936943,
#  -0.004798771347850561,
#  0.024125423282384872,
#  0.010760881006717682,
#  -0.027975520119071007,
#  -0.013025236316025257,
#  -0.01420934870839119,
#  0.014417087659239769,
#  -0.011584912426769733,
#  -0.0020219930447638035,
#  -0.014541731216013432,
#  -0.01265823096036911,
#  0.0038639456033706665,
#  0.011550289578735828,
#  -0.007589398417621851,
#  0.004179016686975956,
#  -0.006093677598983049,
#  0.018004048615694046,
#  0.01774091087281704,
#  0.012748250737786293,
#  -0.010449272580444813,
#  0.011917294934391975,
#  0.013198352418839931,
#  0.018336430191993713,
#  0.013142954558134079,
#  0.00887738075107336,
#  -0.01937512494623661,
#  0.010213835164904594,
#  -0.025067174807190895,
#  -0.0009703143150545657,
#  0.000424999394454062,
#  0.007326262537389994,
#  -0.007097749505192041,
#  -0.00472260033711791,
#  0.02262970246374607,
#  -0.008184917271137238,
#  -0.007727891206741333,
#  0.003559261793270707,
#  0.0024184284266084433,
#  0.005834003910422325,
#  -0.013759247027337551,
#  0.014791017398238182,
#  -0.04057835415005684,
#  -0.003142052562907338,
#  0.009486747905611992,
#  -0.019292030483484268,
#  -0.014527881518006325,
#  -0.0016246922314167023,
#  -0.023100579157471657,
#  0.0065403166227042675,
#  0.009493673220276833,
#  -0.0092305364087224,
#  0.022463511675596237,
#  0.010989394038915634,
#  -0.004109770059585571,
#  -0.018336430191993713,
#  0.003344598226249218,
#  -0.011107112281024456,
#  0.018682662397623062,
#  -0.016563724726438522,
#  -0.016868408769369125,
#  -0.0038189354818314314,
#  -0.02530261129140854,
#  -0.020607709884643555,
#  -0.002930851187556982,
#  0.0075409263372421265,
#  -0.0015078389551490545,
#  -0.016231341287493706,
#  0.005494697019457817,
#  0.004075147211551666,
#  -0.012360471300780773,
#  -0.02078775130212307,
#  -0.02672908641397953,
#  -0.012997537851333618,
#  0.0268675796687603,
#  -0.004833394195884466,
#  0.017560871317982674,
#  0.008780435658991337,
#  0.018862701952457428,
#  -0.0349278524518013,
#  -0.04043986275792122,
#  -0.00178136199247092,
#  -0.01227045152336359,
#  -0.01513724960386753,
#  0.031216248869895935,
#  0.026922976598143578,
#  0.025787336751818657,
#  0.05140848085284233,
#  -0.01255436148494482,
#  0.028197109699249268,
#  -0.005044595804065466,
#  0.0033134373370558023,
#  0.0037635385524481535,
#  0.019485918805003166,
#  -0.02332216687500477,
#  -0.003992051351815462,
#  -0.010158438235521317,
#  -0.004985736217349768,
#  -0.006616487633436918,
#  0.023183673620224,
#  0.002558652078732848,
#  0.002087777014821768,
#  0.014680223539471626,
#  -0.021826446056365967,
#  -0.00019919141777791083,
#  -0.008780435658991337,
#  -0.022463511675596237,
#  -0.010566990822553635,
#  0.030302196741104126,
#  -0.01739468052983284,
#  0.019832151010632515,
#  -0.028446394950151443,
#  -0.011217907071113586,
#  0.024347012862563133,
#  0.025579597800970078,
#  0.020261477679014206,
#  0.00569204892963171,
#  0.010234608314931393,
#  -0.00693155825138092,
#  -0.012256601825356483,
#  0.019472070038318634,
#  -0.014901812188327312,
#  -0.02197878807783127,
#  0.0018263721140101552,
#  -0.026922976598143578,
#  0.006242557428777218,
#  0.008648867718875408,
#  0.022892840206623077,
#  0.014652525074779987,
#  -0.000724489800632,
#  0.026188965886831284,
#  -0.018017897382378578,
#  0.014320142567157745,
#  0.006027893628925085,
#  -0.012221978977322578,
#  -0.004462926648557186,
#  -0.019901396706700325,
#  -0.021549459546804428,
#  -0.04994045943021774,
#  -0.0003122577036265284,
#  -0.01229814998805523,
#  0.0018748445436358452,
#  0.023793041706085205,
#  -0.023529905825853348,
#  0.012893668375909328,
#  -0.011224831454455853,
#  -0.019984493032097816,
#  -0.0032736207358539104,
#  -0.006491844076663256,
#  0.06043820455670357,
#  0.01498490758240223,
#  0.021729500964283943,
#  0.0191535372287035,
#  0.005608953535556793,
#  -0.013662302866578102,
#  0.034540072083473206,
#  -0.004850706085562706,
#  -0.006993880029767752,
#  0.023516057059168816,
#  0.026119718328118324,
#  -0.015303440392017365,
#  -0.014036232605576515,
#  0.006786141078919172,
#  0.003081462113186717,
#  -0.009126666933298111,
#  -0.02092624269425869,
#  0.03032989613711834,
#  -0.003330748761072755,
#  -0.01050466950982809,
#  -0.009805281646549702,
#  -0.0034069197718054056,
#  -0.033681418746709824,
#  0.007984102703630924,
#  -0.016217492520809174,
#  -0.009112818166613579,
#  -0.007804062217473984,
#  0.008544998243451118,
#  -0.023668399080634117,
#  0.003964352887123823,
#  -0.008648867718875408,
#  0.019361276179552078,
#  0.014347841031849384,
#  0.008392656221985817,
#  0.006155999377369881,
#  0.009002024307847023,
#  -0.007270865608006716,
#  0.01014458853751421,
#  0.024028480052947998,
#  0.029221953824162483,
#  -0.005193475168198347,
#  -0.006155999377369881,
#  0.01994294486939907,
#  -0.004798771347850561,
#  0.007534001488238573,
#  0.002477287780493498,
#  -0.0012784604914486408,
#  0.03188101574778557,
#  -0.028944969177246094,
#  -0.010989394038915634,
#  0.008482675999403,
#  0.003760076127946377,
#  0.021591007709503174,
#  -0.0007253554067574441,
#  -0.012035013176500797,
#  -0.024568600580096245,
#  -0.015206496231257915,
#  0.0040024383924901485,
#  0.02545495331287384,
#  -0.0036700558848679066,
#  -0.0048957159742712975,
#  0.003680442925542593,
#  0.004037061706185341,
#  -0.0009729110752232373,
#  0.0050653694197535515,
#  0.002485943492501974,
#  0.0055050840601325035,
#  -0.029859021306037903,
#  -0.012180430814623833,
#  0.003330748761072755,
#  -0.008503450080752373,
#  0.0038085486739873886,
#  0.002984517253935337,
#  -0.018225636333227158,
#  0.022712798789143562,
#  0.0412985160946846,
#  -0.03232419118285179,
#  -0.008967400528490543,
#  0.0017796308966353536,
#  0.004511398728936911,
#  -0.008004876784980297,
#  -0.009881452657282352,
#  -0.00636373832821846,
#  -0.01866881363093853,
#  0.006955794524401426,
#  -0.007755589671432972,
#  0.008995098993182182,
#  -0.026341307908296585,
#  -0.00712544796988368,
#  0.015331138856709003,
#  -0.004764148034155369,
#  0.008544998243451118,
#  -0.008164143189787865,
#  -0.0083095608279109,
#  0.00020903738914057612,
#  0.0036423574201762676,
#  -0.003142052562907338,
#  -0.00034255298669449985,
#  0.014036232605576515,
#  -0.0034138443879783154,
#  0.013814644888043404,
#  -0.016729915514588356,
#  0.00947289913892746,
#  -0.0033013192005455494,
#  0.016508327797055244,
#  0.010795503854751587,
#  -0.02631360851228237,
#  -0.009403652511537075,
#  0.015441933646798134,
#  0.016799161210656166,
#  0.011314851231873035,
#  -0.018682662397623062,
#  -0.015386536717414856,
#  0.0007634408539161086,
#  -0.02593967877328396,
#  0.014057006686925888,
#  0.0040301368571817875,
#  -0.018142540007829666,
#  0.001607380574569106,
#  0.013627679087221622,
#  -0.0006054726545698941,
#  -0.02016453444957733,
#  -0.012540511786937714,
#  -0.007942554540932178,
#  -0.02388998679816723,
#  0.003978202119469643,
#  -0.017630117014050484,
#  -0.0061698486097157,
#  0.008510375395417213,
#  0.02607817016541958,
#  0.020039889961481094,
#  -0.0419909805059433,
#  -0.031077755615115166,
#  -0.012014240026473999,
#  -0.03947041183710098,
#  -0.011633384972810745,
#  -0.011903445236384869,
#  -0.001262880046851933,
#  -0.0009590617846697569,
#  0.022712798789143562,
#  0.006581864319741726,
#  0.03819628059864044,
#  0.011093263514339924,
#  -0.0027144565246999264,
#  -0.01219428051263094,
#  0.006304879207164049,
#  -0.0031282033305615187,
#  -0.02431931346654892,
#  -0.026909127831459045,
#  0.018419526517391205,
#  -0.009272084571421146,
#  -0.00841343030333519,
#  -0.007727891206741333,
#  0.004996123258024454,
#  -0.0072362422943115234,
#  0.037725403904914856,
#  0.012962914071977139,
#  -0.021452516317367554,
#  -0.011917294934391975,
#  -0.00014260417083278298,
#  -0.008510375395417213,
#  0.017450077459216118,
#  0.009417502209544182,
#  -0.015192646533250809,
#  -0.007568624801933765,
#  0.0021466363687068224,
#  -0.00957676861435175,
#  -0.006194084882736206,
#  -0.007437056861817837,
#  0.005553556140512228,
#  0.0011148659978061914,
#  0.004383292980492115,
#  -0.034318484365940094,
#  0.016106698662042618,
#  -0.02624436281621456,
#  -0.010781655088067055,
#  0.03728222846984863,
#  -0.007111598737537861,
#  -0.020261477679014206,
#  0.022712798789143562,
#  0.022158827632665634,
#  -0.00819876603782177,
#  -0.0020912394393235445,
#  0.02030302584171295,
#  -0.003148977179080248,
#  -0.020884696394205093,
#  0.007928705774247646,
#  -0.023086728528141975,
#  -0.027380002662539482,
#  -0.034955549985170364,
#  0.011335625313222408,
#  -0.04121541976928711,
#  -0.00251017976552248,
#  0.009258235804736614,
#  0.012672079727053642,
#  -0.011287152767181396,
#  0.01682686060667038,
#  -0.002659059362486005,
#  -0.025981226935982704,
#  0.0002988412161357701,
#  -0.028390998020768166,
#  0.010580840520560741,
#  -0.019208934158086777,
#  -0.028017068281769753,
#  0.014486334286630154,
#  -0.004147855564951897,
#  -0.0029775926377624273,
#  -0.0070388903841376305,
#  0.0006807780591771007,
#  -0.022380417212843895,
#  0.014444786123931408,
#  0.03218569606542587,
#  -0.001562370453029871,
#  0.011744178831577301,
#  0.19909706711769104,
#  -0.02693682536482811,
#  -0.01653602533042431,
#  0.01537268701940775,
#  -0.010657011531293392,
#  0.005248872563242912,
#  0.007059663999825716,
#  -0.005269646178930998,
#  -0.01438938919454813,
#  0.00031658558873459697,
#  0.01717309094965458,
#  0.01909814029932022,
#  -0.008337259292602539,
#  -0.012318923138082027,
#  -0.01071240846067667,
#  -0.024804038926959038,
#  -0.023003634065389633,
#  -0.021743349730968475,
#  -0.02728305757045746,
#  -0.027989370748400688,
#  0.0077140419743955135,
#  -0.01360690500587225,
#  -0.01205578725785017,
#  -0.023654548451304436,
#  0.006339502055197954,
#  -0.0023145589511841536,
#  -0.013212201185524464,
#  -0.008399580605328083,
#  0.007000804878771305,
#  0.04827854782342911,
#  -0.017366981133818626,
#  0.007464755326509476,
#  0.024097725749015808,
#  0.01830873265862465,
#  -0.013994685374200344,
#  -0.013177578337490559,
#  0.013343769125640392,
#  0.019901396706700325,
#  0.04188018664717674,
#  -0.004573720507323742,
#  0.03301665559411049,
#  -0.01361383032053709,
#  0.01477716863155365,
#  0.005757832899689674,
#  -0.0030260649509727955,
#  0.023142125457525253,
#  ...]

# %% [markdown]
# ## Try Out Cohere
#
# https://docs.cohere.com/docs/embeddings
